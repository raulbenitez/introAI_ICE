# %% [markdown]
# <a href="https://colab.research.google.com/github/raulbenitez/introAI_ICE/blob/main/monedes_clusters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import data, io, filters

image = data.coins()

io.imshow(image)
io.show()

# %%
image.shape
# Out:
# (303, 384)

# %% [markdown]
# redmensionar les dades amb NOBSxNVARS
#
# NOBS = NPIXELS
# NVARS = 1

# %%
import numpy as np

v = np.reshape(image,(image.shape[0]*image.shape[1],1))
v.shape
# Out:
# (116352, 1)

# %%
import matplotlib.pyplot as plt

plt.hist(v,bins=25)
# Out:
# (array([  124.,   597.,  6653., 11680., 10838.,  9634.,  8312.,  6882.,
#          7231.,  6037.,  5273.,  5279.,  5526.,  4355.,  4632.,  4844.,
#          4822.,  4435.,  3593.,  2468.,  1554.,   860.,   531.,   164.,
#            28.]),
#  array([  1.  ,  11.04,  21.08,  31.12,  41.16,  51.2 ,  61.24,  71.28,
#          81.32,  91.36, 101.4 , 111.44, 121.48, 131.52, 141.56, 151.6 ,
#         161.64, 171.68, 181.72, 191.76, 201.8 , 211.84, 221.88, 231.92,
#         241.96, 252.  ]),
#  <BarContainer object of 25 artists>)

# %% [markdown]
# Aplicar un GMM amb 2 gaussianes per identificar els dos grups (fons vs monedes)
